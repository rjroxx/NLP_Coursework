# %%
n=int(input("Enter the value:"))
# Out:
# Enter the value:25

# %% [markdown]
# method 1

# %%
ls=[]
for i in range(1,10000):
  if i>1:
    for k in range(2,i):
      if (i%k)==0 :
        break
    else:
      ls.append(i)
          
print(ls[n-1])
# Out:
# 97

# %% [markdown]
# method 2

# %%
def np(n):
    all = [2]
    f = 2
    while len(a)!=n:
        for s in a:
            if (f%s)==0:
              break
        else:
            a.append(f)
        f += 1
    return a[-1]

print(np(n))
# Out:
# 97
